# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime as dt
from datetime import timedelta

sns.set(rc = {'figure.figsize':(15,10)})

# %%
#read csv + info
hour_drive = pd.read_csv('hour_drive.csv')
hour_drive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52011 entries, 0 to 52010
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      52011 non-null  int64
#  1   timestamp (ms)  52011 non-null  int64
#  2   acc_x           52011 non-null  int64
#  3   acc_y           52011 non-null  int64
#  4   acc_z           52011 non-null  int64
#  5   gyro_x          52011 non-null  float64
#  6   gyro_y          52011 non-null  float64
#  7   gyro_z          52011 non-null  float64
#  8   Speed(Km/h)     52011 non-null  float64
# dtypes: float64(4), int64(5)
# memory usage: 3.6 MB

# %%
#drop column
hour_drive = hour_drive.drop(columns = ['Unnamed: 0'])

# %%
#convert ms into s in new column
hour_drive['seconds'] = hour_drive['timestamp (ms)'] * 0.001
hour_drive
# Out:
#        timestamp (ms)  acc_x  acc_y  acc_z  gyro_x  gyro_y  gyro_z  \
# 0             2019518      0    -64    -64   2.019   0.155   3.584
# 1             2019530    -64     64     96   2.019   0.155   3.584
# 2             2019542    256     32   -224   2.019   0.155   3.584
# 3             2019555    -64      0    320   2.019   0.155   3.584
# 4             2019567     64    128      0   2.019   0.155   3.584
# ...               ...    ...    ...    ...     ...     ...     ...
# 52006         4038485 -13216  -2176    416  -0.095  -0.015   0.061
# 52007         4038498   5408   -352 -10624  -0.095  -0.015   0.061
# 52008         4038510   5568   -480  -2912  -0.095  -0.015   0.061
# 52009         4038523   2368   1216   7168  -0.095  -0.015   0.061
# 52010         4038535   2048    832   9856  -0.095  -0.015   0.061
#
#        Speed(Km/h)   seconds
# 0              0.0  2019.518
# 1              0.0  2019.530
# 2              0.0  2019.542
# 3              0.0  2019.555
# 4              0.0  2019.567
# ...            ...       ...
# 52006         13.6  4038.485
# 52007         13.6  4038.498
# 52008         13.6  4038.510
# 52009         13.6  4038.523
# 52010         13.6  4038.535
#
# [52011 rows x 9 columns]

# %%
#create a clock from the s column
start_time = pd.to_datetime('30/3/2022 18:10:00')
new_datetime = start_time + pd.to_timedelta(hour_drive['seconds'], unit = 's')
hour_drive['Clock'] = new_datetime
hour_drive
# Out:
#        timestamp (ms)  acc_x  acc_y  acc_z  gyro_x  gyro_y  gyro_z  \
# 0             2019518      0    -64    -64   2.019   0.155   3.584
# 1             2019530    -64     64     96   2.019   0.155   3.584
# 2             2019542    256     32   -224   2.019   0.155   3.584
# 3             2019555    -64      0    320   2.019   0.155   3.584
# 4             2019567     64    128      0   2.019   0.155   3.584
# ...               ...    ...    ...    ...     ...     ...     ...
# 52006         4038485 -13216  -2176    416  -0.095  -0.015   0.061
# 52007         4038498   5408   -352 -10624  -0.095  -0.015   0.061
# 52008         4038510   5568   -480  -2912  -0.095  -0.015   0.061
# 52009         4038523   2368   1216   7168  -0.095  -0.015   0.061
# 52010         4038535   2048    832   9856  -0.095  -0.015   0.061
#
#        Speed(Km/h)   seconds                   Clock
# 0              0.0  2019.518 2022-03-30 18:43:39.518
# 1              0.0  2019.530 2022-03-30 18:43:39.530
# 2              0.0  2019.542 2022-03-30 18:43:39.542
# 3              0.0  2019.555 2022-03-30 18:43:39.555
# 4              0.0  2019.567 2022-03-30 18:43:39.567
# ...            ...       ...                     ...
# 52006         13.6  4038.485 2022-03-30 19:17:18.485
# 52007         13.6  4038.498 2022-03-30 19:17:18.498
# 52008         13.6  4038.510 2022-03-30 19:17:18.510
# 52009         13.6  4038.523 2022-03-30 19:17:18.523
# 52010         13.6  4038.535 2022-03-30 19:17:18.535
#
# [52011 rows x 10 columns]

# %%
hour_drive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52011 entries, 0 to 52010
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp (ms)  52011 non-null  int64
#  1   acc_x           52011 non-null  int64
#  2   acc_y           52011 non-null  int64
#  3   acc_z           52011 non-null  int64
#  4   gyro_x          52011 non-null  float64
#  5   gyro_y          52011 non-null  float64
#  6   gyro_z          52011 non-null  float64
#  7   Speed(Km/h)     52011 non-null  float64
#  8   seconds         52011 non-null  float64
#  9   Clock           52011 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(4)
# memory usage: 4.0 MB

# %%
#get rid of date
hour_drive['Clock'] = new_datetime.dt.strftime('%H:%M:%S:%f')

# %%
hour_drive.head(100)
# Out:
#     timestamp (ms)  acc_x  acc_y  acc_z  gyro_x  gyro_y  gyro_z  Speed(Km/h)  \
# 0          2019518      0    -64    -64   2.019   0.155   3.584          0.0
# 1          2019530    -64     64     96   2.019   0.155   3.584          0.0
# 2          2019542    256     32   -224   2.019   0.155   3.584          0.0
# 3          2019555    -64      0    320   2.019   0.155   3.584          0.0
# 4          2019567     64    128      0   2.019   0.155   3.584          0.0
# ..             ...    ...    ...    ...     ...     ...     ...          ...
# 95         2020699   -128    160   -256   2.019   0.155   3.584          0.0
# 96         2020712    160    160    -32   2.019   0.155   3.584          0.0
# 97         2020724    160    224     96   2.019   0.155   3.584          0.0
# 98         2020736    -96     32   -160   2.019   0.155   3.584          0.0
# 99         2020749   -288    -96    -32   2.019   0.155   3.584          0.0
#
#      seconds            Clock  SMA50AX  SMA50AY  SMA50AZ       AMAG  \
# 0   2019.518  18:43:39:518000      NaN      NaN      NaN        NaN
# 1   2019.530  18:43:39:530000      NaN      NaN      NaN        NaN
# 2   2019.542  18:43:39:542000      NaN      NaN      NaN        NaN
# 3   2019.555  18:43:39:555000      NaN      NaN      NaN        NaN
# 4   2019.567  18:43:39:567000      NaN      NaN      NaN        NaN
# ..       ...              ...      ...      ...      ...        ...
# 95  2020.699  18:43:40:699000    10.24    20.48    -2.56  23.040000
# 96  2020.712  18:43:40:712000    11.52    25.60    -3.84  28.334008
# 97  2020.724  18:43:40:724000    19.20    30.72    -3.84  36.429439
# 98  2020.736  18:43:40:736000    12.16    32.00    -8.96  35.385692
# 99  2020.749  18:43:40:749000     5.76    31.36    -8.32  32.952232
#
#           std        2std        3std  SMA50GX  SMA50GY  SMA50GZ
# 0   264.78128  529.562561  794.343841      NaN      NaN      NaN
# 1   264.78128  529.562561  794.343841      NaN      NaN      NaN
# 2   264.78128  529.562561  794.343841      NaN      NaN      NaN
# 3   264.78128  529.562561  794.343841      NaN      NaN      NaN
# 4   264.78128  529.562561  794.343841      NaN      NaN      NaN
# ..        ...         ...         ...      ...      ...      ...
# 95  264.78128  529.562561  794.343841    2.019    0.155    3.584
# 96  264.78128  529.562561  794.343841    2.019    0.155    3.584
# 97  264.78128  529.562561  794.343841    2.019    0.155    3.584
# 98  264.78128  529.562561  794.343841    2.019    0.155    3.584
# 99  264.78128  529.562561  794.343841    2.019    0.155    3.584
#
# [100 rows x 20 columns]

# %%
#filter with rolling average 50 ---> looked more consistent with filtered data provided by zoomo // we could change
hour_drive['SMA50AX'] = hour_drive['acc_x'].rolling(50).mean()
hour_drive['SMA50AY'] = hour_drive['acc_y'].rolling(50).mean()
hour_drive['SMA50AZ'] = hour_drive['acc_z'].rolling(50).mean()
hour_drive['SMA50GX'] = hour_drive['gyro_x'].rolling(50).mean()
hour_drive['SMA50GY'] = hour_drive['gyro_y'].rolling(50).mean()
hour_drive['SMA50GZ'] = hour_drive['gyro_z'].rolling(50).mean()

# %%
#hour_drive.drop(columns = ['SMA200AX', 'SMA200AY', 'SMA200AZ', 'SMA200GX', 'SMA200GY', 'SMA200GZ'], inplace = True)

# %%
#look at min of all columns
print(hour_drive['SMA50AX'].min())
print(hour_drive['SMA50AY'].min())
print(hour_drive['SMA50AZ'].min())
print(hour_drive['SMA50GX'].min())
print(hour_drive['SMA50GY'].min()) 
print(hour_drive['SMA50GZ'].min())
# Out:
# -1551.36
# -851.2
# -1977.6
# -43.817001
# -7.402
# -80.455002

# %%
#look at max for all columns
print(hour_drive['SMA50AX'].max())
print(hour_drive['SMA50AY'].max())
print(hour_drive['SMA50AZ'].max())
print(hour_drive['SMA50GX'].max())
print(hour_drive['SMA50GY'].max()) 
print(hour_drive['SMA50GZ'].max())
# Out:
# 1999.36
# 876.8
# 1639.68
# 15.391000000000002
# 9.203
# 37.088001

# %%
#calculate amag
hour_drive['AMAG'] = (hour_drive['SMA50AX']**2 + hour_drive['SMA50AY']**2 + hour_drive['SMA50AZ']**2)**0.5
hour_drive['AMAG']
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 52006    890.511418
# 52007    800.669927
# 52008    684.971642
# 52009    595.388873
# 52010    572.436980
# Name: AMAG, Length: 52011, dtype: float64

# %%
print(hour_drive['AMAG'].max())
# Out:
# 2283.053764062511

# %%
#plot AMAG
hour_drive.plot(x = 'Clock', y = 'AMAG')
plt.show()

# %%
#calculate std
hour_drive['std'] = hour_drive['AMAG'].std()
hour_drive
# Out:
#        timestamp (ms)  acc_x  acc_y  acc_z  gyro_x  gyro_y  gyro_z  \
# 0             2019518      0    -64    -64   2.019   0.155   3.584
# 1             2019530    -64     64     96   2.019   0.155   3.584
# 2             2019542    256     32   -224   2.019   0.155   3.584
# 3             2019555    -64      0    320   2.019   0.155   3.584
# 4             2019567     64    128      0   2.019   0.155   3.584
# ...               ...    ...    ...    ...     ...     ...     ...
# 52006         4038485 -13216  -2176    416  -0.095  -0.015   0.061
# 52007         4038498   5408   -352 -10624  -0.095  -0.015   0.061
# 52008         4038510   5568   -480  -2912  -0.095  -0.015   0.061
# 52009         4038523   2368   1216   7168  -0.095  -0.015   0.061
# 52010         4038535   2048    832   9856  -0.095  -0.015   0.061
#
#        Speed(Km/h)   seconds            Clock  SMA50AX  SMA50AY  SMA50AZ  \
# 0              0.0  2019.518  18:43:39:518000      NaN      NaN      NaN
# 1              0.0  2019.530  18:43:39:530000      NaN      NaN      NaN
# 2              0.0  2019.542  18:43:39:542000      NaN      NaN      NaN
# 3              0.0  2019.555  18:43:39:555000      NaN      NaN      NaN
# 4              0.0  2019.567  18:43:39:567000      NaN      NaN      NaN
# ...            ...       ...              ...      ...      ...      ...
# 52006         13.6  4038.485  19:17:18:485000  -870.40     3.20  -188.16
# 52007         13.6  4038.498  19:17:18:498000  -734.08    32.00  -318.08
# 52008         13.6  4038.510  19:17:18:510000  -658.56    23.68  -186.88
# 52009         13.6  4038.523  19:17:18:523000  -582.40    83.20   -91.52
# 52010         13.6  4038.535  19:17:18:535000  -563.20    56.96    85.12
#
#              AMAG        std        2std        3std  SMA50GX  SMA50GY  \
# 0             NaN  264.78128  529.562561  794.343841      NaN      NaN
# 1             NaN  264.78128  529.562561  794.343841      NaN      NaN
# 2             NaN  264.78128  529.562561  794.343841      NaN      NaN
# 3             NaN  264.78128  529.562561  794.343841      NaN      NaN
# 4             NaN  264.78128  529.562561  794.343841      NaN      NaN
# ...           ...        ...         ...         ...      ...      ...
# 52006  890.511418  264.78128  529.562561  794.343841   -0.095   -0.015
# 52007  800.669927  264.78128  529.562561  794.343841   -0.095   -0.015
# 52008  684.971642  264.78128  529.562561  794.343841   -0.095   -0.015
# 52009  595.388873  264.78128  529.562561  794.343841   -0.095   -0.015
# 52010  572.436980  264.78128  529.562561  794.343841   -0.095   -0.015
#
#        SMA50GZ
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 52006    0.061
# 52007    0.061
# 52008    0.061
# 52009    0.061
# 52010    0.061
#
# [52011 rows x 20 columns]

# %%
#calculated 2std and 3 std
hour_drive['2std'] = hour_drive['AMAG'].std()*2
hour_drive
hour_drive['3std'] = hour_drive['AMAG'].std()*3
hour_drive
# Out:
#        timestamp (ms)  acc_x  acc_y  acc_z  gyro_x  gyro_y  gyro_z  \
# 0             2019518      0    -64    -64   2.019   0.155   3.584
# 1             2019530    -64     64     96   2.019   0.155   3.584
# 2             2019542    256     32   -224   2.019   0.155   3.584
# 3             2019555    -64      0    320   2.019   0.155   3.584
# 4             2019567     64    128      0   2.019   0.155   3.584
# ...               ...    ...    ...    ...     ...     ...     ...
# 52006         4038485 -13216  -2176    416  -0.095  -0.015   0.061
# 52007         4038498   5408   -352 -10624  -0.095  -0.015   0.061
# 52008         4038510   5568   -480  -2912  -0.095  -0.015   0.061
# 52009         4038523   2368   1216   7168  -0.095  -0.015   0.061
# 52010         4038535   2048    832   9856  -0.095  -0.015   0.061
#
#        Speed(Km/h)   seconds            Clock  SMA50AX  SMA50AY  SMA50AZ  \
# 0              0.0  2019.518  18:43:39:518000      NaN      NaN      NaN
# 1              0.0  2019.530  18:43:39:530000      NaN      NaN      NaN
# 2              0.0  2019.542  18:43:39:542000      NaN      NaN      NaN
# 3              0.0  2019.555  18:43:39:555000      NaN      NaN      NaN
# 4              0.0  2019.567  18:43:39:567000      NaN      NaN      NaN
# ...            ...       ...              ...      ...      ...      ...
# 52006         13.6  4038.485  19:17:18:485000  -870.40     3.20  -188.16
# 52007         13.6  4038.498  19:17:18:498000  -734.08    32.00  -318.08
# 52008         13.6  4038.510  19:17:18:510000  -658.56    23.68  -186.88
# 52009         13.6  4038.523  19:17:18:523000  -582.40    83.20   -91.52
# 52010         13.6  4038.535  19:17:18:535000  -563.20    56.96    85.12
#
#              AMAG        std        2std        3std  SMA50GX  SMA50GY  \
# 0             NaN  264.78128  529.562561  794.343841      NaN      NaN
# 1             NaN  264.78128  529.562561  794.343841      NaN      NaN
# 2             NaN  264.78128  529.562561  794.343841      NaN      NaN
# 3             NaN  264.78128  529.562561  794.343841      NaN      NaN
# 4             NaN  264.78128  529.562561  794.343841      NaN      NaN
# ...           ...        ...         ...         ...      ...      ...
# 52006  890.511418  264.78128  529.562561  794.343841   -0.095   -0.015
# 52007  800.669927  264.78128  529.562561  794.343841   -0.095   -0.015
# 52008  684.971642  264.78128  529.562561  794.343841   -0.095   -0.015
# 52009  595.388873  264.78128  529.562561  794.343841   -0.095   -0.015
# 52010  572.436980  264.78128  529.562561  794.343841   -0.095   -0.015
#
#        SMA50GZ
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 52006    0.061
# 52007    0.061
# 52008    0.061
# 52009    0.061
# 52010    0.061
#
# [52011 rows x 20 columns]

# %%
#y_values = [hour_drive['AMAG'], hour_drive['std'], hour_drive['2std'], hour_drive['3std']]

# %%
#####
####
#####

#takes a lot of time to compute, not seen a graph yet


#######
#####
####
#fig, ax = plt.subplots()
ax.plot(hour_drive['Clock'], hour_drive['AMAG'])
ax.plot(hour_drive['Clock'], hour_drive['std'])
plt.show()

# %%
#another try at visualisations
x = hour_drive['Clock']
y = hour_drive['std']
y2 = hour_drive['2std']
y3 = hour_drive['3std']

# %%
#still cannot make the graph
fig, ax = plt.subplots()
ax.plot(x, y)
ax.plot(x, y)
ax.plot(x, y2)
ax.plot(x, y3)
plt.show()

# %%
#executes but doesnt show
ax.plot(x, y)
plt.show()

# %%
#make list of columns
cols = list(hour_drive.columns.values)
cols
# Out:
# ['timestamp (ms)',
#  'acc_x',
#  'acc_y',
#  'acc_z',
#  'gyro_x',
#  'gyro_y',
#  'gyro_z',
#  'Speed(Km/h)',
#  'seconds',
#  'Clock',
#  'SMA50AX',
#  'SMA50AY',
#  'SMA50AZ',
#  'AMAG',
#  'std',
#  '2std',
#  '3std',
#  'SMA50GX',
#  'SMA50GY',
#  'SMA50GZ']

# %%
#reorder columns
hour_drive = hour_drive[['timestamp (ms)',
 'acc_x',
 'acc_y',
 'acc_z',
 'gyro_x',
 'gyro_y',
 'gyro_z',
 'Speed(Km/h)',
 'seconds',
 'Clock',
 'SMA50AX',
 'SMA50AY',
 'SMA50AZ',
 'AMAG',
 'std',
 '2std',
 '3std',
 'SMA50GX',
 'SMA50GY',
 'SMA50GZ',]]

# %%
hour_drive
# Out:
#        timestamp (ms)  acc_x  acc_y  acc_z  gyro_x  gyro_y  gyro_z  \
# 0             2019518      0    -64    -64   2.019   0.155   3.584
# 1             2019530    -64     64     96   2.019   0.155   3.584
# 2             2019542    256     32   -224   2.019   0.155   3.584
# 3             2019555    -64      0    320   2.019   0.155   3.584
# 4             2019567     64    128      0   2.019   0.155   3.584
# ...               ...    ...    ...    ...     ...     ...     ...
# 52006         4038485 -13216  -2176    416  -0.095  -0.015   0.061
# 52007         4038498   5408   -352 -10624  -0.095  -0.015   0.061
# 52008         4038510   5568   -480  -2912  -0.095  -0.015   0.061
# 52009         4038523   2368   1216   7168  -0.095  -0.015   0.061
# 52010         4038535   2048    832   9856  -0.095  -0.015   0.061
#
#        Speed(Km/h)   seconds            Clock  SMA50AX  SMA50AY  SMA50AZ  \
# 0              0.0  2019.518  18:43:39:518000      NaN      NaN      NaN
# 1              0.0  2019.530  18:43:39:530000      NaN      NaN      NaN
# 2              0.0  2019.542  18:43:39:542000      NaN      NaN      NaN
# 3              0.0  2019.555  18:43:39:555000      NaN      NaN      NaN
# 4              0.0  2019.567  18:43:39:567000      NaN      NaN      NaN
# ...            ...       ...              ...      ...      ...      ...
# 52006         13.6  4038.485  19:17:18:485000  -870.40     3.20  -188.16
# 52007         13.6  4038.498  19:17:18:498000  -734.08    32.00  -318.08
# 52008         13.6  4038.510  19:17:18:510000  -658.56    23.68  -186.88
# 52009         13.6  4038.523  19:17:18:523000  -582.40    83.20   -91.52
# 52010         13.6  4038.535  19:17:18:535000  -563.20    56.96    85.12
#
#              AMAG        std        2std        3std  SMA50GX  SMA50GY  \
# 0             NaN  264.78128  529.562561  794.343841      NaN      NaN
# 1             NaN  264.78128  529.562561  794.343841      NaN      NaN
# 2             NaN  264.78128  529.562561  794.343841      NaN      NaN
# 3             NaN  264.78128  529.562561  794.343841      NaN      NaN
# 4             NaN  264.78128  529.562561  794.343841      NaN      NaN
# ...           ...        ...         ...         ...      ...      ...
# 52006  890.511418  264.78128  529.562561  794.343841   -0.095   -0.015
# 52007  800.669927  264.78128  529.562561  794.343841   -0.095   -0.015
# 52008  684.971642  264.78128  529.562561  794.343841   -0.095   -0.015
# 52009  595.388873  264.78128  529.562561  794.343841   -0.095   -0.015
# 52010  572.436980  264.78128  529.562561  794.343841   -0.095   -0.015
#
#        SMA50GZ
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 52006    0.061
# 52007    0.061
# 52008    0.061
# 52009    0.061
# 52010    0.061
#
# [52011 rows x 20 columns]

# %% [markdown]
# # Manipulation of all_data(events)

# %%
#load csv
all_data = pd.read_csv('all_data.csv')
all_data
# Out:
#       Unnamed: 0  Unnamed: 0.1     Timestamp    AX     AY    AZ         fAX  \
# 0              0           0.0  18:10:09:027   352  -1120 -1088  -44.076183
# 1              1           1.0  18:10:09:118   928     32   768  -35.793819
# 2              2           2.0  18:10:09:204 -8512  14016  5888 -108.783569
# 3              3           3.0  18:10:09:295  2624  15424 -4928  -81.536301
# 4              4           5.0  18:10:09:384    96    512   960  -79.688850
# ...          ...           ...           ...   ...    ...   ...         ...
# 1147         534         561.0  18:18:48:730    32      0    64  -12.116271
# 1148         535         562.0  18:18:48:819     0     32     0  -12.059914
# 1149         536         563.0  18:18:48:909   -32    -96    32  -12.152256
# 1150         537         564.0  18:18:49:003    96     32   128  -11.653515
# 1151         538         565.0  18:18:49:089    32      0    96  -11.452701
#
#              fAY        fAZ        Amag     UL
# 0      55.046425 -97.609222  120.417520  579.6
# 1      54.783489 -92.298302  113.143293  579.6
# 2     212.341125 -55.202663  244.887632  579.6
# 3     428.819519 -88.810295  445.445414  579.6
# 4     430.335266 -80.931335  445.071494  579.6
# ...          ...        ...         ...    ...
# 1147    3.366579  -0.118162   12.575843  235.3
# 1148    3.493540  -0.117621   12.556281  235.3
# 1149    3.054081   0.028960   12.530187  235.3
# 1150    3.181624   0.610724   12.095459  235.3
# 1151    3.167658   1.043506   11.928425  235.3
#
# [1152 rows x 11 columns]

# %%
#drop columns
all_data = all_data.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'])
all_data
# Out:
#          Timestamp    AX     AY    AZ         fAX         fAY        fAZ  \
# 0     18:10:09:027   352  -1120 -1088  -44.076183   55.046425 -97.609222
# 1     18:10:09:118   928     32   768  -35.793819   54.783489 -92.298302
# 2     18:10:09:204 -8512  14016  5888 -108.783569  212.341125 -55.202663
# 3     18:10:09:295  2624  15424 -4928  -81.536301  428.819519 -88.810295
# 4     18:10:09:384    96    512   960  -79.688850  430.335266 -80.931335
# ...            ...   ...    ...   ...         ...         ...        ...
# 1147  18:18:48:730    32      0    64  -12.116271    3.366579  -0.118162
# 1148  18:18:48:819     0     32     0  -12.059914    3.493540  -0.117621
# 1149  18:18:48:909   -32    -96    32  -12.152256    3.054081   0.028960
# 1150  18:18:49:003    96     32   128  -11.653515    3.181624   0.610724
# 1151  18:18:49:089    32      0    96  -11.452701    3.167658   1.043506
#
#             Amag     UL
# 0     120.417520  579.6
# 1     113.143293  579.6
# 2     244.887632  579.6
# 3     445.445414  579.6
# 4     445.071494  579.6
# ...          ...    ...
# 1147   12.575843  235.3
# 1148   12.556281  235.3
# 1149   12.530187  235.3
# 1150   12.095459  235.3
# 1151   11.928425  235.3
#
# [1152 rows x 9 columns]

# %%
#info
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  1152 non-null   object
#  1   AX         1152 non-null   int64
#  2   AY         1152 non-null   int64
#  3   AZ         1152 non-null   int64
#  4   fAX        1152 non-null   float64
#  5   fAY        1152 non-null   float64
#  6   fAZ        1152 non-null   float64
#  7   Amag       1152 non-null   float64
#  8   UL         1152 non-null   float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 81.1+ KB

# %%
#tranform column to datetime 
all_data['Timestamp'] = pd.to_datetime(all_data['Timestamp'], format = '%H:%M:%S:%f')

# %%
#check if transformed
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  1152 non-null   datetime64[ns]
#  1   AX         1152 non-null   int64
#  2   AY         1152 non-null   int64
#  3   AZ         1152 non-null   int64
#  4   fAX        1152 non-null   float64
#  5   fAY        1152 non-null   float64
#  6   fAZ        1152 non-null   float64
#  7   Amag       1152 non-null   float64
#  8   UL         1152 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(3)
# memory usage: 81.1 KB

# %%
#create rolling avg for AX AY AZ
all_data['SMA50AX'] = all_data['AX'].rolling(50).mean()
all_data['SMA50AY'] = all_data['AY'].rolling(50).mean()
all_data['SMA50AZ'] = all_data['AZ'].rolling(50).mean()

# %%
#all_data = all_data.drop(columns=['SMA200AX', 'SMA200AY', 'SMA200AZ'])

# %%
#keep only time - no date
all_data['Timestamp'] = all_data['Timestamp'].dt.strftime('%H:%M:%S:%f')

# %%
all_data
# Out:
#             Timestamp    AX     AY    AZ         fAX         fAY        fAZ  \
# 0     18:10:09,027000   352  -1120 -1088  -44.076183   55.046425 -97.609222
# 1     18:10:09,118000   928     32   768  -35.793819   54.783489 -92.298302
# 2     18:10:09,204000 -8512  14016  5888 -108.783569  212.341125 -55.202663
# 3     18:10:09,295000  2624  15424 -4928  -81.536301  428.819519 -88.810295
# 4     18:10:09,384000    96    512   960  -79.688850  430.335266 -80.931335
# ...               ...   ...    ...   ...         ...         ...        ...
# 1147  18:18:48,730000    32      0    64  -12.116271    3.366579  -0.118162
# 1148  18:18:48,819000     0     32     0  -12.059914    3.493540  -0.117621
# 1149  18:18:48,909000   -32    -96    32  -12.152256    3.054081   0.028960
# 1150  18:18:49,003000    96     32   128  -11.653515    3.181624   0.610724
# 1151  18:18:49,089000    32      0    96  -11.452701    3.167658   1.043506
#
#             Amag     UL  SMA50AX  SMA50AY  SMA50AZ
# 0     120.417520  579.6      NaN      NaN      NaN
# 1     113.143293  579.6      NaN      NaN      NaN
# 2     244.887632  579.6      NaN      NaN      NaN
# 3     445.445414  579.6      NaN      NaN      NaN
# 4     445.071494  579.6      NaN      NaN      NaN
# ...          ...    ...      ...      ...      ...
# 1147   12.575843  235.3    48.00     5.76   -20.48
# 1148   12.556281  235.3    48.64     5.12   -19.20
# 1149   12.530187  235.3    48.64     3.84   -17.28
# 1150   12.095459  235.3    51.20     6.40   -15.36
# 1151   11.928425  235.3    51.84     7.04   -14.72
#
# [1152 rows x 12 columns]

# %%
#look at SMA50AX
all_data.plot(x = 'Timestamp', y = 'SMA50AX')
plt.show()

# %%
#Calculate AMAG
all_data['AMAG'] = (all_data['SMA50AX']**2 + all_data['SMA50AY']**2 + all_data['SMA50AZ']**2)**0.5
all_data
# Out:
#             Timestamp    AX     AY    AZ         fAX         fAY        fAZ  \
# 0     18:10:09,027000   352  -1120 -1088  -44.076183   55.046425 -97.609222
# 1     18:10:09,118000   928     32   768  -35.793819   54.783489 -92.298302
# 2     18:10:09,204000 -8512  14016  5888 -108.783569  212.341125 -55.202663
# 3     18:10:09,295000  2624  15424 -4928  -81.536301  428.819519 -88.810295
# 4     18:10:09,384000    96    512   960  -79.688850  430.335266 -80.931335
# ...               ...   ...    ...   ...         ...         ...        ...
# 1147  18:18:48,730000    32      0    64  -12.116271    3.366579  -0.118162
# 1148  18:18:48,819000     0     32     0  -12.059914    3.493540  -0.117621
# 1149  18:18:48,909000   -32    -96    32  -12.152256    3.054081   0.028960
# 1150  18:18:49,003000    96     32   128  -11.653515    3.181624   0.610724
# 1151  18:18:49,089000    32      0    96  -11.452701    3.167658   1.043506
#
#             Amag     UL  SMA50AX  SMA50AY  SMA50AZ       AMAG
# 0     120.417520  579.6      NaN      NaN      NaN        NaN
# 1     113.143293  579.6      NaN      NaN      NaN        NaN
# 2     244.887632  579.6      NaN      NaN      NaN        NaN
# 3     445.445414  579.6      NaN      NaN      NaN        NaN
# 4     445.071494  579.6      NaN      NaN      NaN        NaN
# ...          ...    ...      ...      ...      ...        ...
# 1147   12.575843  235.3    48.00     5.76   -20.48  52.503409
# 1148   12.556281  235.3    48.64     5.12   -19.20  52.542402
# 1149   12.530187  235.3    48.64     3.84   -17.28  51.760927
# 1150   12.095459  235.3    51.20     6.40   -15.36  53.836137
# 1151   11.928425  235.3    51.84     7.04   -14.72  54.347269
#
# [1152 rows x 13 columns]

# %%
#calculate std, 2std and 3std for amag
all_data['std'] = all_data['AMAG'].std()
all_data['2std'] = all_data['AMAG'].std()*2
all_data['3std'] = all_data['AMAG'].std()*3
all_data
# Out:
#             Timestamp    AX     AY    AZ         fAX         fAY        fAZ  \
# 0     18:10:09,027000   352  -1120 -1088  -44.076183   55.046425 -97.609222
# 1     18:10:09,118000   928     32   768  -35.793819   54.783489 -92.298302
# 2     18:10:09,204000 -8512  14016  5888 -108.783569  212.341125 -55.202663
# 3     18:10:09,295000  2624  15424 -4928  -81.536301  428.819519 -88.810295
# 4     18:10:09,384000    96    512   960  -79.688850  430.335266 -80.931335
# ...               ...   ...    ...   ...         ...         ...        ...
# 1147  18:18:48,730000    32      0    64  -12.116271    3.366579  -0.118162
# 1148  18:18:48,819000     0     32     0  -12.059914    3.493540  -0.117621
# 1149  18:18:48,909000   -32    -96    32  -12.152256    3.054081   0.028960
# 1150  18:18:49,003000    96     32   128  -11.653515    3.181624   0.610724
# 1151  18:18:49,089000    32      0    96  -11.452701    3.167658   1.043506
#
#             Amag     UL  SMA50AX  SMA50AY  SMA50AZ       AMAG         std  \
# 0     120.417520  579.6      NaN      NaN      NaN        NaN  395.258988
# 1     113.143293  579.6      NaN      NaN      NaN        NaN  395.258988
# 2     244.887632  579.6      NaN      NaN      NaN        NaN  395.258988
# 3     445.445414  579.6      NaN      NaN      NaN        NaN  395.258988
# 4     445.071494  579.6      NaN      NaN      NaN        NaN  395.258988
# ...          ...    ...      ...      ...      ...        ...         ...
# 1147   12.575843  235.3    48.00     5.76   -20.48  52.503409  395.258988
# 1148   12.556281  235.3    48.64     5.12   -19.20  52.542402  395.258988
# 1149   12.530187  235.3    48.64     3.84   -17.28  51.760927  395.258988
# 1150   12.095459  235.3    51.20     6.40   -15.36  53.836137  395.258988
# 1151   11.928425  235.3    51.84     7.04   -14.72  54.347269  395.258988
#
#             2std         3std
# 0     790.517976  1185.776964
# 1     790.517976  1185.776964
# 2     790.517976  1185.776964
# 3     790.517976  1185.776964
# 4     790.517976  1185.776964
# ...          ...          ...
# 1147  790.517976  1185.776964
# 1148  790.517976  1185.776964
# 1149  790.517976  1185.776964
# 1150  790.517976  1185.776964
# 1151  790.517976  1185.776964
#
# [1152 rows x 16 columns]

# %% [markdown]
# # ACCEL 1&2

# %%
#load csvs
accel_1 = pd.read_csv('accel_1.csv')
accel_2 = pd.read_csv('accel_2.csv')

# %%
#append csvs
both_accel = accel_1.append(accel_2)

# %%
#check result
both_accel
# Out:
#         Time    X    Y   Z        X_f       Y_f         Z_f        Amag  \
# 0    2918276    0  -32   0   1.068721 -0.504631   -0.231132    1.204259
# 1    2918374    0   64  64   1.067315 -0.442127   -0.089711    1.158743
# 2    2918471   64  -32  32   1.150048 -0.472716   -0.019123    1.243558
# 3    2918569  -32  160 -96   1.106470 -0.317224   -0.229926    1.173786
# 4    2918666  -32  -32   0   1.062978 -0.347992   -0.229421    1.141777
# ..       ...  ...  ...  ..        ...       ...         ...         ...
# 257  3033658    0  -32  64 -39.390537  6.099705 -135.872971  141.599029
# 258  3033755 -128  -32 -32 -39.715687  5.994855 -135.206390  141.046241
# 259  3033853  -32  -32 -32 -39.687428  5.890501 -134.546951  140.401823
# 260  3033950  -32  -64   0 -39.659370  5.698927 -133.690964  139.565817
# 261  3033953  -32    0   0 -39.631512  5.683327 -132.843552  138.745689
#
#          UL
# 0     84.08
# 1     84.08
# 2     84.08
# 3     84.08
# 4     84.08
# ..      ...
# 257  116.84
# 258  116.84
# 259  116.84
# 260  116.84
# 261  116.84
#
# [474 rows x 9 columns]

# %%
#transform ms into s 
both_accel['seconds'] = both_accel['Time']*0.001
both_accel
# Out:
#         Time    X    Y   Z        X_f       Y_f         Z_f        Amag  \
# 0    2918276    0  -32   0   1.068721 -0.504631   -0.231132    1.204259
# 1    2918374    0   64  64   1.067315 -0.442127   -0.089711    1.158743
# 2    2918471   64  -32  32   1.150048 -0.472716   -0.019123    1.243558
# 3    2918569  -32  160 -96   1.106470 -0.317224   -0.229926    1.173786
# 4    2918666  -32  -32   0   1.062978 -0.347992   -0.229421    1.141777
# ..       ...  ...  ...  ..        ...       ...         ...         ...
# 257  3033658    0  -32  64 -39.390537  6.099705 -135.872971  141.599029
# 258  3033755 -128  -32 -32 -39.715687  5.994855 -135.206390  141.046241
# 259  3033853  -32  -32 -32 -39.687428  5.890501 -134.546951  140.401823
# 260  3033950  -32  -64   0 -39.659370  5.698927 -133.690964  139.565817
# 261  3033953  -32    0   0 -39.631512  5.683327 -132.843552  138.745689
#
#          UL   seconds
# 0     84.08  2918.276
# 1     84.08  2918.374
# 2     84.08  2918.471
# 3     84.08  2918.569
# 4     84.08  2918.666
# ..      ...       ...
# 257  116.84  3033.658
# 258  116.84  3033.755
# 259  116.84  3033.853
# 260  116.84  3033.950
# 261  116.84  3033.953
#
# [474 rows x 10 columns]

# %%
#create a clock with ms and timedelta
start_time_1 = pd.to_datetime('30/3/2022 18:00:00')
new_datetime = start_time_1 + pd.to_timedelta(both_accel['seconds'], unit = 's')
both_accel['Clock'] = new_datetime
both_accel
# Out:
#         Time    X    Y   Z        X_f       Y_f         Z_f        Amag  \
# 0    2918276    0  -32   0   1.068721 -0.504631   -0.231132    1.204259
# 1    2918374    0   64  64   1.067315 -0.442127   -0.089711    1.158743
# 2    2918471   64  -32  32   1.150048 -0.472716   -0.019123    1.243558
# 3    2918569  -32  160 -96   1.106470 -0.317224   -0.229926    1.173786
# 4    2918666  -32  -32   0   1.062978 -0.347992   -0.229421    1.141777
# ..       ...  ...  ...  ..        ...       ...         ...         ...
# 257  3033658    0  -32  64 -39.390537  6.099705 -135.872971  141.599029
# 258  3033755 -128  -32 -32 -39.715687  5.994855 -135.206390  141.046241
# 259  3033853  -32  -32 -32 -39.687428  5.890501 -134.546951  140.401823
# 260  3033950  -32  -64   0 -39.659370  5.698927 -133.690964  139.565817
# 261  3033953  -32    0   0 -39.631512  5.683327 -132.843552  138.745689
#
#          UL   seconds                   Clock
# 0     84.08  2918.276 2022-03-30 18:48:38.276
# 1     84.08  2918.374 2022-03-30 18:48:38.374
# 2     84.08  2918.471 2022-03-30 18:48:38.471
# 3     84.08  2918.569 2022-03-30 18:48:38.569
# 4     84.08  2918.666 2022-03-30 18:48:38.666
# ..      ...       ...                     ...
# 257  116.84  3033.658 2022-03-30 18:50:33.658
# 258  116.84  3033.755 2022-03-30 18:50:33.755
# 259  116.84  3033.853 2022-03-30 18:50:33.853
# 260  116.84  3033.950 2022-03-30 18:50:33.950
# 261  116.84  3033.953 2022-03-30 18:50:33.953
#
# [474 rows x 11 columns]

# %%
#remove date, only time
both_accel['Clock'] = new_datetime.dt.strftime('%H:%M:%S:%f')

# %%
#check result
both_accel
# Out:
#         Time    X    Y   Z        X_f       Y_f         Z_f        Amag  \
# 0    2918276    0  -32   0   1.068721 -0.504631   -0.231132    1.204259
# 1    2918374    0   64  64   1.067315 -0.442127   -0.089711    1.158743
# 2    2918471   64  -32  32   1.150048 -0.472716   -0.019123    1.243558
# 3    2918569  -32  160 -96   1.106470 -0.317224   -0.229926    1.173786
# 4    2918666  -32  -32   0   1.062978 -0.347992   -0.229421    1.141777
# ..       ...  ...  ...  ..        ...       ...         ...         ...
# 257  3033658    0  -32  64 -39.390537  6.099705 -135.872971  141.599029
# 258  3033755 -128  -32 -32 -39.715687  5.994855 -135.206390  141.046241
# 259  3033853  -32  -32 -32 -39.687428  5.890501 -134.546951  140.401823
# 260  3033950  -32  -64   0 -39.659370  5.698927 -133.690964  139.565817
# 261  3033953  -32    0   0 -39.631512  5.683327 -132.843552  138.745689
#
#          UL   seconds            Clock
# 0     84.08  2918.276  18:48:38:276000
# 1     84.08  2918.374  18:48:38:374000
# 2     84.08  2918.471  18:48:38:471000
# 3     84.08  2918.569  18:48:38:569000
# 4     84.08  2918.666  18:48:38:666000
# ..      ...       ...              ...
# 257  116.84  3033.658  18:50:33:658000
# 258  116.84  3033.755  18:50:33:755000
# 259  116.84  3033.853  18:50:33:853000
# 260  116.84  3033.950  18:50:33:950000
# 261  116.84  3033.953  18:50:33:953000
#
# [474 rows x 11 columns]

# %%
#create rolling avg for X Y Z
both_accel['SMA50AX'] = both_accel['X'].rolling(50).mean()
both_accel['SMA50AY'] = both_accel['Y'].rolling(50).mean()
both_accel['SMA50AZ'] = both_accel['Z'].rolling(50).mean()
both_accel
# Out:
#         Time    X    Y   Z        X_f       Y_f         Z_f        Amag  \
# 0    2918276    0  -32   0   1.068721 -0.504631   -0.231132    1.204259
# 1    2918374    0   64  64   1.067315 -0.442127   -0.089711    1.158743
# 2    2918471   64  -32  32   1.150048 -0.472716   -0.019123    1.243558
# 3    2918569  -32  160 -96   1.106470 -0.317224   -0.229926    1.173786
# 4    2918666  -32  -32   0   1.062978 -0.347992   -0.229421    1.141777
# ..       ...  ...  ...  ..        ...       ...         ...         ...
# 257  3033658    0  -32  64 -39.390537  6.099705 -135.872971  141.599029
# 258  3033755 -128  -32 -32 -39.715687  5.994855 -135.206390  141.046241
# 259  3033853  -32  -32 -32 -39.687428  5.890501 -134.546951  140.401823
# 260  3033950  -32  -64   0 -39.659370  5.698927 -133.690964  139.565817
# 261  3033953  -32    0   0 -39.631512  5.683327 -132.843552  138.745689
#
#          UL   seconds            Clock  SMA50AX  SMA50AY  SMA50AZ
# 0     84.08  2918.276  18:48:38:276000      NaN      NaN      NaN
# 1     84.08  2918.374  18:48:38:374000      NaN      NaN      NaN
# 2     84.08  2918.471  18:48:38:471000      NaN      NaN      NaN
# 3     84.08  2918.569  18:48:38:569000      NaN      NaN      NaN
# 4     84.08  2918.666  18:48:38:666000      NaN      NaN      NaN
# ..      ...       ...              ...      ...      ...      ...
# 257  116.84  3033.658  18:50:33:658000   -51.84   126.08  -234.88
# 258  116.84  3033.755  18:50:33:755000   -43.52   123.52  -232.32
# 259  116.84  3033.853  18:50:33:853000   -40.96   122.88  -227.20
# 260  116.84  3033.950  18:50:33:950000   -39.68   124.16  -232.32
# 261  116.84  3033.953  18:50:33:953000   -35.20   129.92  -239.36
#
# [474 rows x 14 columns]

# %%
#Calculate AMAG
both_accel['AMAG'] = (both_accel['SMA50AX']**2 + both_accel['SMA50AY']**2 + both_accel['SMA50AZ']**2)**0.5
both_accel
# Out:
#         Time    X    Y   Z        X_f       Y_f         Z_f        Amag  \
# 0    2918276    0  -32   0   1.068721 -0.504631   -0.231132    1.204259
# 1    2918374    0   64  64   1.067315 -0.442127   -0.089711    1.158743
# 2    2918471   64  -32  32   1.150048 -0.472716   -0.019123    1.243558
# 3    2918569  -32  160 -96   1.106470 -0.317224   -0.229926    1.173786
# 4    2918666  -32  -32   0   1.062978 -0.347992   -0.229421    1.141777
# ..       ...  ...  ...  ..        ...       ...         ...         ...
# 257  3033658    0  -32  64 -39.390537  6.099705 -135.872971  141.599029
# 258  3033755 -128  -32 -32 -39.715687  5.994855 -135.206390  141.046241
# 259  3033853  -32  -32 -32 -39.687428  5.890501 -134.546951  140.401823
# 260  3033950  -32  -64   0 -39.659370  5.698927 -133.690964  139.565817
# 261  3033953  -32    0   0 -39.631512  5.683327 -132.843552  138.745689
#
#          UL   seconds            Clock  SMA50AX  SMA50AY  SMA50AZ        AMAG
# 0     84.08  2918.276  18:48:38:276000      NaN      NaN      NaN         NaN
# 1     84.08  2918.374  18:48:38:374000      NaN      NaN      NaN         NaN
# 2     84.08  2918.471  18:48:38:471000      NaN      NaN      NaN         NaN
# 3     84.08  2918.569  18:48:38:569000      NaN      NaN      NaN         NaN
# 4     84.08  2918.666  18:48:38:666000      NaN      NaN      NaN         NaN
# ..      ...       ...              ...      ...      ...      ...         ...
# 257  116.84  3033.658  18:50:33:658000   -51.84   126.08  -234.88  271.573501
# 258  116.84  3033.755  18:50:33:755000   -43.52   123.52  -232.32  266.690388
# 259  116.84  3033.853  18:50:33:853000   -40.96   122.88  -227.20  261.528308
# 260  116.84  3033.950  18:50:33:950000   -39.68   124.16  -232.32  266.388420
# 261  116.84  3033.953  18:50:33:953000   -35.20   129.92  -239.36  274.611464
#
# [474 rows x 15 columns]

# %%
#calculate std, 2std and 3 std for AMAG
both_accel['std'] = both_accel['AMAG'].std()
both_accel['2std'] = both_accel['AMAG'].std()*2
both_accel['3std'] = both_accel['AMAG'].std()*3
both_accel
# Out:
#         Time    X    Y   Z        X_f       Y_f         Z_f        Amag  \
# 0    2918276    0  -32   0   1.068721 -0.504631   -0.231132    1.204259
# 1    2918374    0   64  64   1.067315 -0.442127   -0.089711    1.158743
# 2    2918471   64  -32  32   1.150048 -0.472716   -0.019123    1.243558
# 3    2918569  -32  160 -96   1.106470 -0.317224   -0.229926    1.173786
# 4    2918666  -32  -32   0   1.062978 -0.347992   -0.229421    1.141777
# ..       ...  ...  ...  ..        ...       ...         ...         ...
# 257  3033658    0  -32  64 -39.390537  6.099705 -135.872971  141.599029
# 258  3033755 -128  -32 -32 -39.715687  5.994855 -135.206390  141.046241
# 259  3033853  -32  -32 -32 -39.687428  5.890501 -134.546951  140.401823
# 260  3033950  -32  -64   0 -39.659370  5.698927 -133.690964  139.565817
# 261  3033953  -32    0   0 -39.631512  5.683327 -132.843552  138.745689
#
#          UL   seconds            Clock  SMA50AX  SMA50AY  SMA50AZ        AMAG  \
# 0     84.08  2918.276  18:48:38:276000      NaN      NaN      NaN         NaN
# 1     84.08  2918.374  18:48:38:374000      NaN      NaN      NaN         NaN
# 2     84.08  2918.471  18:48:38:471000      NaN      NaN      NaN         NaN
# 3     84.08  2918.569  18:48:38:569000      NaN      NaN      NaN         NaN
# 4     84.08  2918.666  18:48:38:666000      NaN      NaN      NaN         NaN
# ..      ...       ...              ...      ...      ...      ...         ...
# 257  116.84  3033.658  18:50:33:658000   -51.84   126.08  -234.88  271.573501
# 258  116.84  3033.755  18:50:33:755000   -43.52   123.52  -232.32  266.690388
# 259  116.84  3033.853  18:50:33:853000   -40.96   122.88  -227.20  261.528308
# 260  116.84  3033.950  18:50:33:950000   -39.68   124.16  -232.32  266.388420
# 261  116.84  3033.953  18:50:33:953000   -35.20   129.92  -239.36  274.611464
#
#            std       2std        3std
# 0    245.48338  490.96676  736.450139
# 1    245.48338  490.96676  736.450139
# 2    245.48338  490.96676  736.450139
# 3    245.48338  490.96676  736.450139
# 4    245.48338  490.96676  736.450139
# ..         ...        ...         ...
# 257  245.48338  490.96676  736.450139
# 258  245.48338  490.96676  736.450139
# 259  245.48338  490.96676  736.450139
# 260  245.48338  490.96676  736.450139
# 261  245.48338  490.96676  736.450139
#
# [474 rows x 18 columns]
