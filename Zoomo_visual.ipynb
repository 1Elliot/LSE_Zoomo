# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
accel1=pd.read_csv('Accelerator1_cleaned.csv')

# %%
accel1.head
# Out:
# <bound method NDFrame.head of         Time    X     Y     Z        X_f       Y_f        Z_f
# 0    2918276    0   -32     0   1.068721 -0.504631  -0.231132
# 1    2918374    0    64    64   1.067315 -0.442127  -0.089711
# 2    2918471   64   -32    32   1.150048 -0.472716  -0.019123
# 3    2918569  -32   160   -96   1.106470 -0.317224  -0.229926
# 4    2918666  -32   -32     0   1.062978 -0.347992  -0.229421
# ..       ...  ...   ...   ...        ...       ...        ...
# 207  2940166  800 -1344 -1312 -15.814420 -3.397115 -30.774044
# 208  2940263 -896   544  -608 -18.281284 -1.684881 -33.244183
# 209  2940361  544  -576   576 -16.682217 -3.495255 -30.618296
# 210  2940458 -384   864   160 -17.735546 -0.738091 -29.790318
# 211  2940556 -480  -192   640 -19.067039 -1.354533 -26.882576
#
# [212 rows x 7 columns]>

# %%
accel1.drop(['X', 'Y', 'Z'], axis=1)
# Out:
#         Time        X_f       Y_f        Z_f
# 0    2918276   1.068721 -0.504631  -0.231132
# 1    2918374   1.067315 -0.442127  -0.089711
# 2    2918471   1.150048 -0.472716  -0.019123
# 3    2918569   1.106470 -0.317224  -0.229926
# 4    2918666   1.062978 -0.347992  -0.229421
# ..       ...        ...       ...        ...
# 207  2940166 -15.814420 -3.397115 -30.774044
# 208  2940263 -18.281284 -1.684881 -33.244183
# 209  2940361 -16.682217 -3.495255 -30.618296
# 210  2940458 -17.735546 -0.738091 -29.790318
# 211  2940556 -19.067039 -1.354533 -26.882576
#
# [212 rows x 4 columns]

# %%
# Chart for Forward/reverse over time
sns.pointplot(x='Time', y='X_f', data = accel1)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='X_f'>

# %%
# Chart for Up/Down over time
sns.pointplot(x='Time', y='Y_f', data = accel1)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Y_f'>

# %%
# Chart for Left/Right over time
sns.pointplot(x='Time', y='Z_f', data = accel1)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Z_f'>

# %%
accel2=pd.read_csv('Accelerator2_cleaned.csv')

# %%
accel2.drop(['X', 'Y', 'Z'], axis=1)
# Out:
#         Time        X_f        Y_f         Z_f
# 0    3002645 -25.849033  12.145277  -52.598858
# 1    3002743 -25.972031  12.371145  -51.784473
# 2    3002889 -26.094332  12.423964  -51.151520
# 3    3002986 -26.113277  12.476519  -51.047153
# 4    3003084 -25.620377  12.614525  -50.423370
# ..       ...        ...        ...         ...
# 257  3033658 -39.390537   6.099705 -135.872971
# 258  3033755 -39.715687   5.994855 -135.206390
# 259  3033853 -39.687428   5.890501 -134.546951
# 260  3033950 -39.659370   5.698927 -133.690964
# 261  3033953 -39.631512   5.683327 -132.843552
#
# [262 rows x 4 columns]

# %%
# Chart for Forward/reverse over time
sns.pointplot(x='Time', y='X_f', data = accel2)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='X_f'>

# %%
# Chart for Up/Down over time
sns.pointplot(x='Time', y='Y_f', data = accel2)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Y_f'>

# %%
# Chart for Left/Right over time
sns.pointplot(x='Time', y='Z_f', data = accel2)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Z_f'>
